# %%
import pandas as pd

# %%
sample = pd.read_csv('/Users/superyao/project/kml/zengjunyao/data/idp_export_idp_25560202_提现团伙统计.csv')
print(sample.shape)
# Out:
# (483, 1)

# %%
sample
# Out:
#          userid
# 0    5248133582
# 1    4786416885
# 2    4917976750
# 3     210681723
# 4    5143012032
# ..          ...
# 478  3624833012
# 479  4834646603
# 480  4503899347
# 481  2427353691
# 482  5078318615
#
# [483 rows x 1 columns]

# %%
feature = pd.read_csv('/Users/superyao/project/kml/zengjunyao/user_info_multi_tables_20260225_112727.csv')
feature
# Out:
#      is_gid_15d user_name                                            applist  \
# 0             0      谢嘻嘻.  58同城,Microsoft 365 (Office),QQ,QQ浏览器,东方财富,中国移动...
# 1             0     叶狸狐假面  58同城,BOSS直聘,QQ浏览器,UC浏览器,UC浏览器极速版,WPS Office,七猫...
# 2             0       NaN                                                NaN
# 3             0        木头  QQ,QQ浏览器,i 漫游,今日头条,今日头条极速版,天天有余,应用宝,微信,快手,快手极速...
# 4             0      烤肉好吃  58同城,HttpCanary,QQ浏览器,WPS Office,今日头条,去哪儿旅行,应用...
# ..          ...       ...                                                ...
# 472           0       NaN  ,58同城,UC浏览器,WPS Office,一念逍遥,京东,今日头条,今日头条极速版,优酷...
# 473           0      平安幸福                                                NaN
# 474           0   7465潜水艇  58同城,QQ,QQ浏览器,SakuraFrp 启动器,UC浏览器,WPS Office,中...
# 475           0       NaN                                                NaN
# 476           0       渔小妹  58同城,QQ,QQ浏览器,WPS Office,京东,今日头条,优酷视频,喜马拉雅,好看视...
#
# ...

# %%
print(feature.shape)
# Out:
# (474, 29)

# %%
feature['device_factor']
# Out:
# 0      ['','acCharger','batteryExcept','batteryExcept...
# 1                        ['','acCharger','noLockScreen']
# 2                                    ['','noLockScreen']
# 3                           ['','acCharger','developer']
# 4                                    ['','noLockScreen']
#                              ...
# 469                                                   []
# 470                                  ['','noLockScreen']
# 471    ['','acCharger','batteryExcept','batteryExcept...
# 472                                                   []
# 473                      ['','developer','noLockScreen']
# Name: device_factor, Length: 474, dtype: object
